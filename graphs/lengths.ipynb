# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt

def get_csv_lengths(folder_path):
    lengths = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            csv_path = os.path.join(folder_path, filename)
            with open(csv_path, 'r') as csv_file:
                csv_length = sum(1 for line in csv_file)
                lengths.append(csv_length)
    return lengths

def plot_histogram(lengths, folder_name):
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.histplot(lengths, bins=20, kde=True, color='orange', edgecolor='black')
    # plt.title(f'Distribution of Game Length for MCTS with {folder_name[12:]} simulations', fontsize=16)
    plt.title(f'', fontsize=16)

    plt.xlabel('Length of the Game', fontsize=18)
    plt.ylabel('Frequency', fontsize=18)
    plt.show()

if __name__ == "__main__":
    folder_paths = ["/Users/Yousef/Desktop/Study Files/Junior/CS 238/final/CS238-Final/data/simulations_20",
                    "/Users/Yousef/Desktop/Study Files/Junior/CS 238/final/CS238-Final/data/simulations_50",
                    "/Users/Yousef/Desktop/Study Files/Junior/CS 238/final/CS238-Final/data/simulations_100",
                    "/Users/Yousef/Desktop/Study Files/Junior/CS 238/final/CS238-Final/data/simulations_200"]

    for folder_path in folder_paths:
        folder_name = os.path.basename(folder_path)
        csv_lengths = get_csv_lengths(folder_path)
        plot_histogram(csv_lengths, folder_name)

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt

def get_csv_lengths(folder_path):
    lengths = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            csv_path = os.path.join(folder_path, filename)
            with open(csv_path, 'r') as csv_file:
                csv_length = sum(1 for line in csv_file)
                lengths.append(csv_length)
    return lengths

def plot_histogram(lengths):
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.histplot(lengths, bins=20, kde=True, color='orange', edgecolor='black')
    # plt.title('Distribution of Game Length for Random Policy', fontsize=16)
    plt.title('', fontsize=16)
    plt.xlabel('Length of the Game', fontsize=18)
    plt.ylabel('Frequency', fontsize=18)
    plt.show()

if __name__ == "__main__":
    folder_path = "/Users/Yousef/Desktop/Study Files/Junior/CS 238/final/CS238-Final/random"
    csv_lengths = get_csv_lengths(folder_path)
    plot_histogram(csv_lengths)
